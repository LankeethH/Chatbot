# %%
import nltk
from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
import json
import pickle


from google.colab import drive
drive.mount('/content/drive')


import numpy as np
from keras.models import Sequential
from keras.layers import Dense, Activation, Dropout
from keras.optimizers import SGD
import random

words=[]
classes = []
documents = []
ignore_words = ['?', '!']
data_file = open('/content/drive/MyDrive/Chatbot-app/data.json').read()
intents = json.loads(data_file)


for intent in intents['intents']:
    for pattern in intent['patterns']:

        #tokenize each word
        w = nltk.word_tokenize(pattern)
        words.extend(w)
        #add documents in the corpus
        documents.append((w, intent['tag']))

        # add to our classes list
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

# lemmaztize and lower each word and remove duplicates
words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))
# sort classes
classes = sorted(list(set(classes)))
# documents = combination between patterns and intents
print (len(documents), "documents")
# classes = intents
print (len(classes), "classes", classes)
# words = all words, vocabulary
print (len(words), "unique lemmatized words", words)


pickle.dump(words,open('texts.pkl','wb'))
pickle.dump(classes,open('labels.pkl','wb'))

# create our training data
training = []
# create an empty array for our output
output_empty = [0] * len(classes)
# training set, bag of words for each sentence
for doc in documents:
    # initialize our bag of words
    bag = []
    # list of tokenized words for the pattern
    pattern_words = doc[0]
    # lemmatize each word - create base word, in attempt to represent related words
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    # create our bag of words array with 1, if word match found in current pattern
    for w in words:
        bag.append(1) if w in pattern_words else bag.append(0)

    # output is a '0' for each tag and '1' for current tag (for each pattern)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1

    training.append([bag, output_row])
# shuffle our features and turn into np.array
random.shuffle(training)
training = np.array(training)
# create train and test lists. X - patterns, Y - intents
train_x = list(training[:,0])
train_y = list(training[:,1])
print("Training data created")


# Create model - 3 layers. First layer 128 neurons, second layer 64 neurons and 3rd output layer contains number of neurons
# equal to number of intents to predict output intent with softmax
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

# Compile model. Stochastic gradient descent with Nesterov accelerated gradient gives good results for this model
sgd = SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

#fitting and saving the model
hist = model.fit(np.array(train_x), np.array(train_y), epochs=200, batch_size=5, verbose=1)
model.save('/content/drive/MyDrive/Chatbot-app/model.h5', hist)

print("model created")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# 47 documents
# 9 classes ['adverse_drug', 'blood_pressure', 'blood_pressure_search', 'goodbye', 'greeting', 'hospital_search', 'options', 'pharmacy_search', 'thanks']
# 88 unique lemmatized words ["'s", ',', 'a', 'adverse', 'all', 'anyone', 'are', 'awesome', 'be', 'behavior', 'blood', 'by', 'bye', 'can', 'causing', 'chatting', 'check', 'could', 'data', 'day', 'detail', 'do', 'dont', 'drug', 'entry', 'find', 'for', 'give', 'good', 'goodbye', 'have', 'hello', 'help', 'helpful', 'helping', 'hey', 'hi', 'history', 'hola', 'hospital', 'how', 'i', 'id', 'is', 'later', 'list', 'load', 'locate', 'log', 'looking', 'lookup', 'management', 'me', 'module', 'nearby', 'next', 'nice', 'of', 'offered', 'open', 'patient', 'pharmacy', 'pressure', 'provide', 'reaction', 'related', 'result', 'search', 'searching', 'see', 'show', 'suitable', 'support', 'task', 'thank', 'thanks', 'that', 'there', 'till', 'time', 'to', 'transfer', 'up', 'want', 'what', 'which', 'with', 'you']
# Training data created
# <ipython-input-8-13acfd8118d2>:78: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   training = np.array(training)
# Epoch 1/200
# 10/10 [==============================] - 1s 5ms/step - loss: 2.2345 - accuracy: 0.1064
# Epoch 2/200
# 10/10 [==============================] - 0s 3ms/step - loss: 2.1327 - accuracy: 0.2128
# Epoch 3/200
# 10/10 [==============================] - 0s 3ms/step - loss: 2.1212 - accuracy: 0.1915
# Epoch 4/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.9950 - accuracy: 0.4043
# Epoch 5/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.9239 - accuracy: 0.2766
# Epoch 6/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.8932 - accuracy: 0.4255
# Epoch 7/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.7035 - accuracy: 0.5319
# Epoch 8/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.5701 - accuracy: 0.5532
# Epoch 9/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.4518 - accuracy: 0.5957
# Epoch 10/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.1906 - accuracy: 0.6809
# Epoch 11/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.2232 - accuracy: 0.5957
# Epoch 12/200
# 10/10 [==============================] - 0s 4ms/step - loss: 1.0781 - accuracy: 0.7660
# Epoch 13/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.0743 - accuracy: 0.7872
# Epoch 14/200
# 10/10 [==============================] - 0s 3ms/step - loss: 1.1054 - accuracy: 0.6809
# Epoch 15/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7376 - accuracy: 0.8085
# Epoch 16/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.7162 - accuracy: 0.7660
# Epoch 17/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6037 - accuracy: 0.9362
# Epoch 18/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.6182 - accuracy: 0.8085
# Epoch 19/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4653 - accuracy: 0.8936
# Epoch 20/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3963 - accuracy: 0.9149
# Epoch 21/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.5041 - accuracy: 0.8298
# Epoch 22/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4156 - accuracy: 0.9149
# Epoch 23/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3727 - accuracy: 0.9149
# Epoch 24/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3954 - accuracy: 0.8723
# Epoch 25/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3424 - accuracy: 0.9149
# Epoch 26/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.4450 - accuracy: 0.8723
# Epoch 27/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2711 - accuracy: 0.9574
# Epoch 28/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2764 - accuracy: 0.9574
# Epoch 29/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3637 - accuracy: 0.9149
# Epoch 30/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3379 - accuracy: 0.9362
# Epoch 31/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.3027 - accuracy: 0.9149
# Epoch 32/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2080 - accuracy: 0.9362
# Epoch 33/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2543 - accuracy: 0.9574
# Epoch 34/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2498 - accuracy: 0.9362
# Epoch 35/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1982 - accuracy: 0.9787
# Epoch 36/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2164 - accuracy: 1.0000
# Epoch 37/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.2283 - accuracy: 0.9149
# Epoch 38/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1796 - accuracy: 0.9574
# Epoch 39/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1998 - accuracy: 0.9362
# Epoch 40/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1311 - accuracy: 0.9362
# Epoch 41/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1452 - accuracy: 0.9574
# Epoch 42/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1480 - accuracy: 0.9362
# Epoch 43/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1288 - accuracy: 1.0000
# Epoch 44/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0937 - accuracy: 1.0000
# Epoch 45/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1035 - accuracy: 0.9787
# Epoch 46/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0476 - accuracy: 1.0000
# Epoch 47/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1217 - accuracy: 0.9574
# Epoch 48/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1233 - accuracy: 0.9787
# Epoch 49/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0764 - accuracy: 1.0000
# Epoch 50/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1737 - accuracy: 0.9362
# Epoch 51/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1065 - accuracy: 0.9787
# Epoch 52/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0845 - accuracy: 1.0000
# Epoch 53/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1378 - accuracy: 0.9574
# Epoch 54/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1091 - accuracy: 0.9787
# Epoch 55/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1354 - accuracy: 0.9149
# Epoch 56/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1109 - accuracy: 0.9574
# Epoch 57/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1100 - accuracy: 0.9787
# Epoch 58/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0372 - accuracy: 1.0000
# Epoch 59/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0885 - accuracy: 1.0000
# Epoch 60/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0760 - accuracy: 0.9787
# Epoch 61/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0339 - accuracy: 1.0000
# Epoch 62/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0641 - accuracy: 0.9787
# Epoch 63/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0897 - accuracy: 0.9574
# Epoch 64/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0595 - accuracy: 1.0000
# Epoch 65/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0361 - accuracy: 1.0000
# Epoch 66/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0487 - accuracy: 1.0000
# Epoch 67/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0593 - accuracy: 0.9787
# Epoch 68/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0471 - accuracy: 1.0000
# Epoch 69/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0744 - accuracy: 0.9787
# Epoch 70/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0498 - accuracy: 0.9787
# Epoch 71/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0712 - accuracy: 1.0000
# Epoch 72/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1111 - accuracy: 0.9574
# Epoch 73/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0301 - accuracy: 1.0000
# Epoch 74/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0392 - accuracy: 1.0000
# Epoch 75/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0484 - accuracy: 0.9787
# Epoch 76/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0654 - accuracy: 1.0000
# Epoch 77/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1377 - accuracy: 0.9574
# Epoch 78/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0497 - accuracy: 0.9787
# Epoch 79/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0612 - accuracy: 0.9787
# Epoch 80/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.1635 - accuracy: 0.9362
# Epoch 81/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0990 - accuracy: 0.9787
# Epoch 82/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0191 - accuracy: 1.0000
# Epoch 83/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0425 - accuracy: 1.0000
# Epoch 84/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0602 - accuracy: 0.9787
# Epoch 85/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0310 - accuracy: 1.0000
# Epoch 86/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0357 - accuracy: 1.0000
# Epoch 87/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0476 - accuracy: 1.0000
# Epoch 88/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0620 - accuracy: 0.9787
# Epoch 89/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0488 - accuracy: 0.9787
# Epoch 90/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.1023 - accuracy: 0.9574
# Epoch 91/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0983 - accuracy: 0.9574
# Epoch 92/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0107 - accuracy: 1.0000
# Epoch 93/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0201 - accuracy: 1.0000
# Epoch 94/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0524 - accuracy: 0.9574
# Epoch 95/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0319 - accuracy: 1.0000
# Epoch 96/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0775 - accuracy: 0.9787
# Epoch 97/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0190 - accuracy: 1.0000
# Epoch 98/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0328 - accuracy: 1.0000
# Epoch 99/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0113 - accuracy: 1.0000
# Epoch 100/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0604 - accuracy: 1.0000
# Epoch 101/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0234 - accuracy: 1.0000
# Epoch 102/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0506 - accuracy: 0.9787
# Epoch 103/200
# 10/10 [==============================] - 0s 4ms/step - loss: 0.0847 - accuracy: 0.9787
# Epoch 104/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0220 - accuracy: 1.0000
# Epoch 105/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0369 - accuracy: 1.0000
# Epoch 106/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0235 - accuracy: 1.0000
# Epoch 107/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0162 - accuracy: 1.0000
# Epoch 108/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0200 - accuracy: 1.0000
# Epoch 109/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0563 - accuracy: 1.0000
# Epoch 110/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0811 - accuracy: 0.9787
# Epoch 111/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0223 - accuracy: 1.0000
# Epoch 112/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0353 - accuracy: 1.0000
# Epoch 113/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0109 - accuracy: 1.0000
# Epoch 114/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0230 - accuracy: 1.0000
# Epoch 115/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0687 - accuracy: 0.9574
# Epoch 116/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0406 - accuracy: 1.0000
# Epoch 117/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0160 - accuracy: 1.0000
# Epoch 118/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0110 - accuracy: 1.0000
# Epoch 119/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0775 - accuracy: 0.9787
# Epoch 120/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0432 - accuracy: 0.9787
# Epoch 121/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0399 - accuracy: 0.9787
# Epoch 122/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0081 - accuracy: 1.0000
# Epoch 123/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0269 - accuracy: 1.0000
# Epoch 124/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0339 - accuracy: 1.0000
# Epoch 125/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 126/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0413 - accuracy: 1.0000
# Epoch 127/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0240 - accuracy: 1.0000
# Epoch 128/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0387 - accuracy: 0.9787
# Epoch 129/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0362 - accuracy: 1.0000
# Epoch 130/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0393 - accuracy: 1.0000
# Epoch 131/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0163 - accuracy: 1.0000
# Epoch 132/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0558 - accuracy: 1.0000
# Epoch 133/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0195 - accuracy: 1.0000
# Epoch 134/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0934 - accuracy: 0.9787
# Epoch 135/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0432 - accuracy: 0.9787
# Epoch 136/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0768 - accuracy: 0.9787
# Epoch 137/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0375 - accuracy: 1.0000
# Epoch 138/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0465 - accuracy: 0.9787
# Epoch 139/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0209 - accuracy: 1.0000
# Epoch 140/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0338 - accuracy: 1.0000
# Epoch 141/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0159 - accuracy: 1.0000
# Epoch 142/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0253 - accuracy: 0.9787
# Epoch 143/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0768 - accuracy: 0.9787
# Epoch 144/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 145/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0408 - accuracy: 0.9787
# Epoch 146/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0382 - accuracy: 0.9787
# Epoch 147/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0175 - accuracy: 1.0000
# Epoch 148/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0549 - accuracy: 0.9787
# Epoch 149/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0527 - accuracy: 0.9787
# Epoch 150/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 151/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 152/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0424 - accuracy: 0.9787
# Epoch 153/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0678 - accuracy: 0.9787
# Epoch 154/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0116 - accuracy: 1.0000
# Epoch 155/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0306 - accuracy: 0.9787
# Epoch 156/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0786 - accuracy: 0.9787
# Epoch 157/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0189 - accuracy: 1.0000
# Epoch 158/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0176 - accuracy: 1.0000
# Epoch 159/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0614 - accuracy: 0.9787
# Epoch 160/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0161 - accuracy: 1.0000
# Epoch 161/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 162/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0157 - accuracy: 1.0000
# Epoch 163/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0462 - accuracy: 1.0000
# Epoch 164/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0246 - accuracy: 0.9787
# Epoch 165/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0564 - accuracy: 0.9787
# Epoch 166/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 167/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.1534 - accuracy: 0.9574
# Epoch 168/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0132 - accuracy: 1.0000
# Epoch 169/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0310 - accuracy: 1.0000
# Epoch 170/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0216 - accuracy: 1.0000
# Epoch 171/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0377 - accuracy: 1.0000
# Epoch 172/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0504 - accuracy: 0.9787
# Epoch 173/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0525 - accuracy: 0.9787
# Epoch 174/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0326 - accuracy: 0.9787
# Epoch 175/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 176/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0184 - accuracy: 1.0000
# Epoch 177/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0086 - accuracy: 1.0000
# Epoch 178/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0312 - accuracy: 1.0000
# Epoch 179/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0738 - accuracy: 0.9787
# Epoch 180/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0127 - accuracy: 1.0000
# Epoch 181/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0580 - accuracy: 0.9787
# Epoch 182/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0123 - accuracy: 1.0000
# Epoch 183/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0075 - accuracy: 1.0000
# Epoch 184/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0106 - accuracy: 1.0000
# Epoch 185/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0135 - accuracy: 1.0000
# Epoch 186/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0202 - accuracy: 1.0000
# Epoch 187/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0528 - accuracy: 0.9787
# Epoch 188/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 189/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0203 - accuracy: 1.0000
# Epoch 190/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0057 - accuracy: 1.0000
# Epoch 191/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0230 - accuracy: 0.9787
# Epoch 192/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0147 - accuracy: 1.0000
# Epoch 193/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 194/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0093 - accuracy: 1.0000
# Epoch 195/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0202 - accuracy: 1.0000
# Epoch 196/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 197/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0396 - accuracy: 0.9787
# Epoch 198/200
# 10/10 [==============================] - 0s 3ms/step - loss: 0.0096 - accuracy: 1.0000
# Epoch 199/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0038 - accuracy: 1.0000
# Epoch 200/200
# 10/10 [==============================] - 0s 2ms/step - loss: 0.0180 - accuracy: 1.0000
# model created
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3000: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
